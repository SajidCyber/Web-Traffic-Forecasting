# %%
# Analyze Dataset Notebook

# %%
import pandas as pd

file_path = 'web_traffic.csv'
df = pd.read_csv(file_path)

print('--- Dataset Shape ---')
print(df.shape)

print('\n--- Columns & Data Types ---')
print(df.dtypes)

print('\n--- First 5 Rows ---')
print(df.head())

print('\n--- Null Values Count ---')
print(df.isnull().sum())

print('\n--- Summary Statistics ---')
print(df.describe(include='all'))

print('\n--- Correlation Matrix ---')
print(df.corr(numeric_only=True))
# Out:
# --- Dataset Shape ---
# (1339, 14)
#
# --- Columns & Data Types ---
# ds                       object
# y                         int64
# unique_visitors           int64
# sessions                  int64
# bounce_rate             float64
# avg_session_duration    float64
# pages_per_session       float64
# ad_spend                float64
# seo_score               float64
# social_trend_index      float64
# campaign_flag             int64
# holiday_flag              int64
# weekday                   int64
# month                     int64
# dtype: object
#
# --- First 5 Rows ---
#                     ds     y  unique_visitors  sessions  bounce_rate  \
# 0  2022-01-01 00:00:00  2497              845       868     0.420583
# 1  2022-01-02 00:00:00  2535              838       888     0.442014
# 2  2022-01-03 00:00:00  2981              962      1004     0.467618
# 3  2022-01-04 00:00:00  3048             1021      1015     0.461985
# ...
